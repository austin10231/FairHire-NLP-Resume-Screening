# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score

# %%
df = pd.read_csv('/Users/mr.tian/Desktop/AI_Resume_Screening.csv')

# %%
df.head()
# Out:
#    Resume_ID              Name                                        Skills  \
# 0          1        Ashley Ali                      TensorFlow, NLP, Pytorch
# 1          2      Wesley Roman  Deep Learning, Machine Learning, Python, SQL
# 2          3     Corey Sanchez         Ethical Hacking, Cybersecurity, Linux
# 3          4  Elizabeth Carney                   Python, Pytorch, TensorFlow
# 4          5        Julie Hill                              SQL, React, Java
#
#    Experience (Years) Education                Certifications  \
# 0                  10      B.Sc                           NaN
# 1                  10       MBA                     Google ML
# 2                   1       MBA  Deep Learning Specialization
# 3                   7    B.Tech                 AWS Certified
# 4                   4       PhD                           NaN
#
#                 Job Role Recruiter Decision  Salary Expectation ($)  \
# 0          AI Researcher               Hire                  104895
# 1         Data Scientist               Hire                  113002
# 2  Cybersecurity Analyst               Hire                   71766
# 3          AI Researcher               Hire                   46848
# 4      Software Engineer               Hire                   87441
#
#    Projects Count  AI Score (0-100)
# 0               8               100
# 1               1               100
# 2               7                70
# 3               0                95
# 4               9               100

# %%
role = "Data Scientist"
df_role = df[df["Job Role"] == role].copy()

# %%
y = (df_role["Recruiter Decision"] == "Hire").astype(int)

# %%
X_text = (
    df_role["Skills"].fillna("") + " " +
    df_role["Certifications"].fillna("")
)

# %%
X_train_text, X_test_text, y_train, y_test = train_test_split(
    X_text,
    y,
    test_size=0.3,
    random_state=42
)

test_index = X_test_text.index

# %%
tfidf = TfidfVectorizer(
    max_features=5000,
    stop_words="english",
    ngram_range=(1, 2)
)

X_train_tfidf = tfidf.fit_transform(X_train_text)
X_test_tfidf = tfidf.transform(X_test_text)

# %%
nlp_model = LogisticRegression(max_iter=1000)
nlp_model.fit(X_train_tfidf, y_train)

y_pred_nlp = nlp_model.predict(X_test_tfidf)
y_prob_nlp = nlp_model.predict_proba(X_test_tfidf)[:, 1]

print("Accuracy:", accuracy_score(y_test, y_pred_nlp))
print("AUC:", roc_auc_score(y_test, y_prob_nlp))
# Out:
# Accuracy: 0.8311688311688312
# AUC: 0.5709134615384615

# %%
df_eval_nlp = df_role.loc[test_index].copy()
df_eval_nlp["y_pred"] = y_pred_nlp

# %%
def exp_bucket(x):
    if x < 3:
        return "Junior"
    elif x < 7:
        return "Mid"
    else:
        return "Senior"

df_role['Experience Level'] = df_role['Experience (Years)'].apply(exp_bucket)

# %%
selection_rate_nlp = (
    df_eval_nlp
    .groupby("Experience Level")["y_pred"]
    .mean()
    .sort_values(ascending=False)
)

selection_rate_nlp
# Out:
# Experience Level
# Junior    1.0
# Mid       1.0
# Senior    1.0
# Name: y_pred, dtype: float64

# %%
baseline_group = "Mid"
baseline_rate = selection_rate_nlp.loc[baseline_group]

dp_diff_nlp = selection_rate_nlp - baseline_rate
disparate_impact_nlp = selection_rate_nlp / baseline_rate

audit_nlp = (
    pd.DataFrame({
        "Selection Rate": selection_rate_nlp,
        "DP Difference": dp_diff_nlp,
        "Disparate Impact": disparate_impact_nlp
    })
    .round(3)
)

audit_nlp
# Out:
#                   Selection Rate  DP Difference  Disparate Impact
# Experience Level
# Junior                       1.0            0.0               1.0
# Mid                          1.0            0.0               1.0
# Senior                       1.0            0.0               1.0

# %%
nlp_model = LogisticRegression(
    max_iter=1000,
    C=0.5,                  
    class_weight="balanced",  
    solver="liblinear"
)

nlp_model.fit(X_train_tfidf, y_train)
# Out:
# LogisticRegression(C=0.5, class_weight='balanced', max_iter=1000,
#                    solver='liblinear')

# %%
y_prob_nlp = nlp_model.predict_proba(X_test_tfidf)[:, 1]

threshold = 0.6
y_pred_nlp = (y_prob_nlp >= threshold).astype(int)

print("Accuracy:", accuracy_score(y_test, y_pred_nlp))
print("AUC:", roc_auc_score(y_test, y_prob_nlp))
# Out:
# Accuracy: 0.2727272727272727
# AUC: 0.563701923076923

# %%
from sklearn.metrics import confusion_matrix, classification_report

print(confusion_matrix(y_test, y_pred_nlp))
print(classification_report(y_test, y_pred_nlp))
# Out:
# [[11  2]
#  [54 10]]
#               precision    recall  f1-score   support
#
#            0       0.17      0.85      0.28        13
#            1       0.83      0.16      0.26        64
#
#     accuracy                           0.27        77
#    macro avg       0.50      0.50      0.27        77
# weighted avg       0.72      0.27      0.27        77

# %%
for t in [0.4, 0.5, 0.6, 0.7]:
    y_tmp = (y_prob_nlp >= t).astype(int)
    print(f"\nThreshold = {t}")
    print("Accuracy:", accuracy_score(y_test, y_tmp))
# Out:
# Threshold = 0.4
# Accuracy: 0.7532467532467533
#
# Threshold = 0.5
# Accuracy: 0.5974025974025974
#
# Threshold = 0.6
# Accuracy: 0.2727272727272727
#
# Threshold = 0.7
# Accuracy: 0.18181818181818182

# %%
df_eval_nlp["hire_probability"] = y_prob_nlp

# %%
def decision_label(p, threshold=0.6):
    if p >= threshold:
        return "Recommend Interview"
    elif p >= threshold - 0.1:
        return "Borderline"
    else:
        return "Unlikely"
    
df_eval_nlp["decision_label"] = df_eval_nlp["hire_probability"].apply(decision_label)

# %%
group_avg = (
    df_eval_nlp
    .groupby("Experience Level")["hire_probability"]
    .mean()
)

df_eval_nlp["group_avg_probability"] = df_eval_nlp["Experience Level"].map(group_avg)

# %%
THRESHOLD = 0.4

y_pred_nlp = (y_prob_nlp >= THRESHOLD).astype(int)

# %%
df_eval_nlp["hire_probability"] = y_prob_nlp
df_eval_nlp["y_pred"] = y_pred_nlp

# %%
def decision_label(p, threshold=0.4):
    if p >= threshold:
        return "Recommend Interview"
    elif p >= threshold - 0.1:
        return "Borderline"
    else:
        return "Unlikely"

df_eval_nlp["decision_label"] = df_eval_nlp["hire_probability"].apply(decision_label)

# %%
def exp_bucket(x):
    if x < 3:
        return "Junior"
    elif x < 7:
        return "Mid"
    else:
        return "Senior"

df_eval_nlp["Experience Level"] = df_eval_nlp["Experience (Years)"].apply(exp_bucket)

# %%
selection_rate_nlp = (
    df_eval_nlp
    .groupby("Experience Level")["y_pred"]
    .mean()
)

selection_rate_nlp
# Out:
# Experience Level
# Junior    0.947368
# Mid       0.866667
# Senior    0.892857
# Name: y_pred, dtype: float64

# %%
baseline_group = "Mid"
baseline_rate = selection_rate_nlp.loc[baseline_group]

dp_difference = selection_rate_nlp - baseline_rate
disparate_impact = selection_rate_nlp / baseline_rate

audit_nlp = (
    pd.DataFrame({
        "Selection Rate": selection_rate_nlp,
        "DP Difference": dp_difference,
        "Disparate Impact": disparate_impact
    })
    .round(3)
)

audit_nlp
# Out:
#                   Selection Rate  DP Difference  Disparate Impact
# Experience Level
# Junior                     0.947          0.081             1.093
# Mid                        0.867          0.000             1.000
# Senior                     0.893          0.026             1.030

# %%
group_avg_prob = (
    df_eval_nlp
    .groupby("Experience Level")["hire_probability"]
    .mean()
)

df_eval_nlp["group_avg_probability"] = (
    df_eval_nlp["Experience Level"]
    .map(group_avg_prob)
)

# %%
def fairness_context(row):
    if row["hire_probability"] >= row["group_avg_probability"]:
        return "Above group average"
    else:
        return "Below group average"

df_eval_nlp["fairness_context"] = df_eval_nlp.apply(fairness_context, axis=1)

# %%
final_output = df_eval_nlp[[
    "Name",
    "Experience (Years)",
    "Experience Level",
    "Skills",
    "Certifications",
    "hire_probability",
    "decision_label",
    "group_avg_probability",
    "fairness_context"
]].sort_values("hire_probability", ascending=False)

final_output.head(10)
# Out:
#                 Name  Experience (Years) Experience Level  \
# 284    Tara Williams                   7           Senior
# 379  Mr. Keith Smith                   2           Junior
# 378    Zachary Lynch                   8           Senior
# 173     Phillip Shaw                   9           Senior
# 421    Stephen Mason                   2           Junior
# 270        Amy Poole                   0           Junior
# 959   Evan Rodriguez                   3              Mid
# 554       Frank Hale                   1           Junior
# 304      Tina Howard                   6              Mid
# 429     Karen Wright                  10           Senior
#
#                                            Skills  \
# 284                         Python, Deep Learning
# 379  SQL, Python, Deep Learning, Machine Learning
# 378                                   SQL, Python
# 173                                   SQL, Python
# 421                         Python, Deep Learning
# 270                 Machine Learning, SQL, Python
# 959                 Machine Learning, SQL, Python
# 554  Machine Learning, Python, Deep Learning, SQL
# 304                 SQL, Python, Machine Learning
# 429                 SQL, Python, Machine Learning
#
#                    Certifications  hire_probability       decision_label  \
# 284                           NaN          0.727581  Recommend Interview
# 379                     Google ML          0.675093  Recommend Interview
# 378  Deep Learning Specialization          0.653444  Recommend Interview
# 173  Deep Learning Specialization          0.653444  Recommend Interview
# 421                 AWS Certified          0.628502  Recommend Interview
# 270                     Google ML          0.628134  Recommend Interview
# 959                     Google ML          0.628134  Recommend Interview
# 554                     Google ML          0.619470  Recommend Interview
# 304                 AWS Certified          0.611770  Recommend Interview
# 429                 AWS Certified          0.611770  Recommend Interview
#
#      group_avg_probability     fairness_context
# 284               0.523789  Above group average
# 379               0.524144  Above group average
# 378               0.523789  Above group average
# 173               0.523789  Above group average
# 421               0.524144  Above group average
# 270               0.524144  Above group average
# 959               0.489525  Above group average
# 554               0.524144  Above group average
# 304               0.489525  Above group average
# 429               0.523789  Above group average

# %%
final_output.to_csv("nlp_resume_screening_results.csv", index=False)
audit_nlp.to_csv("fairness_audit_results.csv")

# %%
import joblib

joblib.dump(nlp_model, "nlp_resume_model.pkl")
joblib.dump(tfidf, "tfidf_vectorizer.pkl")
# Out:
# ['tfidf_vectorizer.pkl']

# %%
import json

config = {
    "threshold": 0.4,
    "model": "LogisticRegression + TFIDF",
    "task": "Resume Screening (NLP)"
}

with open("model_config.json", "w") as f:
    json.dump(config, f, indent=2)
